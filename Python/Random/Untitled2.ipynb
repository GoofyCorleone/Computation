# %%
from sympy import *
init_printing(use_unicode=False)
x = Symbol('x')

# %% [markdown]
# # Punto 1

# %%
integrate(x**3 * (x**4 - 1)**2,x)
# Out:
#  12    8    4
# x     x    x
# --- - -- + --
# 12    4    4

# %% [markdown]
# # Punto 2

# %%
integrate(exp(x)*cos(x),x)
# Out:
#  x           x
# e *sin(x)   e *cos(x)
# --------- + ---------
#     2           2

# %% [markdown]
# # Punto 3

# %%
integrate(x / ( (x+1)*(x**2 + 1) ) ,x)
# Out:
#                   / 2    \
#   log(x + 1)   log\x  + 1/   atan(x)
# - ---------- + ----------- + -------
#       2             4           2

# %% [markdown]
# # Punto 4

# %%
integrate( 1 / (x**2 * sqrt(144+x**2) ) ,x)
# Out:
#     __________
#    /  2
# -\/  x  + 144
# ---------------
#      144*x

# %% [markdown]
# # Punto 5
