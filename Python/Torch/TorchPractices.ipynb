# %%
import time
import torch
from torch import nn

# %% [markdown]
# ## 1. Create tensor directly on the target device

# %%
start = time.time()

for i in range(100):
    cpu_tensor = torch.ones((100,64,64))
    gpu_tensor = cpu_tensor.rocml()

print('Total time = ' , start - time.time())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       3 for i in range(100):
#       4     cpu_tensor = torch.ones((100,64,64))
# ----> 5     gpu_tensor = cpu_tensor.rocml()
#       7 print('Total time = ' , start - time.time())
#
# AttributeError: 'Tensor' object has no attribute 'rocml'
